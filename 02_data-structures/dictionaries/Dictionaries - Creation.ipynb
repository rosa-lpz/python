# %% [markdown]
# # Creating a dictionary

# %% [markdown]
# ## Creating a dictionary inside curly braces

# %%
# dictionary with integer keys
my_dict = {1: 'apple', 2: 'ball'}
my_dict
# Out:
# {1: 'apple', 2: 'ball'}

# %%
# dictionary with mixed keys
my_dict2 = {'name': 'John', 1: [2, 4, 3]}
my_dict2
# Out:
# {'name': 'John', 1: [2, 4, 3]}

# %% [markdown]
# ## Creating a dictionary using dict()

# %%
# using dict()
my_dict3 = dict({1:'apple', 2:'ball'})
my_dict3
# Out:
# {1: 'apple', 2: 'ball'}

# %%
# from sequence having each item as a pair
my_dict4 = dict([(1,'apple'), (2,'ball')])
my_dict4
# Out:
# {1: 'apple', 2: 'ball'}

# %% [markdown]
# ## Creating a dictionary using Dictionary comprehension

# %%
myDict5 = {x: x**2 for x in [1,2,3,4,5]}
print(myDict5)
# Out:
# {1: 1, 2: 4, 3: 9, 4: 16, 5: 25}

# %% [markdown]
# # REFERENCES
#
# ## Courses
#
# - Udacity - AI Programming with Python
#
#
# ## Websites
# * ### Geeks for Geeks
# 	* Python Data structures: [https://www.geeksforgeeks.org/python-data-structures/](https://www.geeksforgeeks.org/python-data-structures/)
#
#
# * ### W3Schools
# 	* https://www.w3schools.com/python/python_dictionaries.asp
# * ### Programiz
# 	* https://www.programiz.com/python-programming/dictionary
# * ### StrataScratch
# 	* https://www.stratascratch.com/blog/python-dictionaries-master-key-value-data-structures
