# %%
import matplotlib.pyplot as plt
import pandas as pd
import numpy as np

# %% [markdown]
# ## Time series DF creation

# %% [markdown]
#     * np.random.randn(100) generates 100 random numbers from a standard normal distribution.
#     * .cumsum() calculates the cumulative sum to simulate a trend over time (more realistic for time series).

# %%
# Create a time series index
dates = pd.date_range(start='2023-01-01', periods=100, freq='D')
values = np.random.randn(100).cumsum()

# %%
dates
# Out:
# DatetimeIndex(['2023-01-01', '2023-01-02', '2023-01-03', '2023-01-04',
#                '2023-01-05', '2023-01-06', '2023-01-07', '2023-01-08',
#                '2023-01-09', '2023-01-10', '2023-01-11', '2023-01-12',
#                '2023-01-13', '2023-01-14', '2023-01-15', '2023-01-16',
#                '2023-01-17', '2023-01-18', '2023-01-19', '2023-01-20',
#                '2023-01-21', '2023-01-22', '2023-01-23', '2023-01-24',
#                '2023-01-25', '2023-01-26', '2023-01-27', '2023-01-28',
#                '2023-01-29', '2023-01-30', '2023-01-31', '2023-02-01',
#                '2023-02-02', '2023-02-03', '2023-02-04', '2023-02-05',
#                '2023-02-06', '2023-02-07', '2023-02-08', '2023-02-09',
#                '2023-02-10', '2023-02-11', '2023-02-12', '2023-02-13',
#                '2023-02-14', '2023-02-15', '2023-02-16', '2023-02-17',
#                '2023-02-18', '2023-02-19', '2023-02-20', '2023-02-21',
# ...

# %%
values
# Out:
# array([ -1.61797944,  -1.61804215,  -2.81775789,  -3.06683314,
#         -3.94636747,  -3.98424502,  -3.79552058,  -5.3451984 ,
#         -5.19965297,  -3.13362138,  -2.43543097,  -1.2979429 ,
#         -1.83642279,  -1.2599253 ,  -1.14212874,  -2.21304416,
#         -2.85988545,  -2.5266998 ,  -4.33957366,  -4.86861682,
#         -6.39415896,  -5.64026986,  -5.86620269,  -6.02040284,
#         -5.43900869,  -5.15546409,  -5.36719303,  -6.64901869,
#         -5.70869981,  -5.65144425,  -3.60978183,  -2.54363998,
#         -1.59133425,  -2.31571309,  -0.96631995,  -0.48467784,
#         -1.4157341 ,  -1.38491023,  -2.75693573,  -2.58216093,
#         -3.12901475,  -3.31177197,  -4.37366627,  -4.35200596,
#         -5.71192425,  -6.92659425,  -6.49961216,  -5.88800418,
#         -5.16161865,  -4.2711996 ,  -4.68519326,  -4.33093972,
#         -5.05640413,  -4.48868736,  -4.28188817,  -5.64300682,
#         -5.82823544,  -4.97112715,  -3.80014814,  -4.85971628,
# ...

# %%
# Create a DataFrame
df = pd.DataFrame({'Date': dates, 'Value': values})
df.set_index('Date', inplace=True)
df
# Out:
#                 Value
# Date
# 2023-01-01  -1.617979
# 2023-01-02  -1.618042
# 2023-01-03  -2.817758
# 2023-01-04  -3.066833
# 2023-01-05  -3.946367
# ...               ...
# 2023-04-06 -16.605057
# 2023-04-07 -15.795672
# 2023-04-08 -16.125050
# 2023-04-09 -15.834344
# 2023-04-10 -14.700483
#
# [100 rows x 1 columns]

# %%
# Plotting
plt.figure(figsize=(12, 6))
plt.plot(df.index, df['Value'], label='Value', color='blue')
plt.title('Time Series Plot')
plt.xlabel('Date')
plt.ylabel('Value')
plt.grid(True)
plt.legend()
plt.tight_layout()
plt.show()
