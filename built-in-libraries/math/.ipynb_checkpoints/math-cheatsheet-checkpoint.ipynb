# %% [markdown]
# # Math Built-in Library

# %% [markdown]
# # Square Root

# %%
import math

# %% [markdown]
# $\sqrt{50}$

# %%
print("Math sqrt(50):", math.sqrt(50))
# Out:
# Math sqrt(50): 7.0710678118654755

# %% [markdown]
# $\sqrt[3]{27} = 3$

# %%
print("Math cube root of 27:", math.pow(27, 1/3))
# Out:
# Math cube root of 27: 3.0
