# %% [markdown]
# # Referencias
#
# **Tutorials**
# * https://www.geeksforgeeks.org/python-seaborn-tutorial/
# * https://medium.com/wicds/data-visualization-for-beginners-in-seaborn-f762a0292598
#
# **Heatmap**
# * https://pythonbasics.org/seaborn-heatmap/
# * https://towardsdatascience.com/5-ways-to-use-a-seaborn-heatmap-python-tutorial-c79950f5add3
# * https://seaborn.pydata.org/generated/seaborn.heatmap.html
#
# **Histogram**
# * https://edu.gcfglobal.org/es/estadistica-basica/histograma-de-datos-/1/
# * https://www.python-graph-gallery.com/20-basic-histogram-seaborn
#
# **Plotting Categorical data**
# * https://seaborn.pydata.org/tutorial/categorical.html
# * https://towardsdatascience.com/a-complete-guide-to-plotting-categorical-variables-with-seaborn-bfe54db66bec
# * https://mathalope.co.uk/2015/03/19/descriptive-statistics-can-we-plot-histogram-for-categorical-variables/
#
# **Setting the size**
# * https://drawingfromdata.com/pandas/seaborn/matplotlib/visualization/setting-figure-size-matplotlib-seaborn.html
# * https://www.statology.org/seaborn-figure-size/
#
# **Videos**
# * https://www.youtube.com/watch?v=BubBhIMKpl0
# * Seaborn is the Easier Matplotlib: https://youtu.be/ooqXQ37XHMM

# %% [markdown]
# # **Import libraries**

# %%
import seaborn as sns
import pandas as pd
import matplotlib.pyplot as plt

# %% [markdown]
# # **Datos**

# %% [markdown]
# ## Datos de vuelos

# %%
# initialize list of lists
data = [['1949', 'Jan', 112], ['1949', 'Feb', 118], ['1949', 'Mar', 132], ['1949', 'Apr', 129], ['1949', 'May', 108],
        ['1950', 'Jan', 110], ['1950', 'Feb', 121], ['1950', 'Mar', 112], ['1950', 'Apr', 138], ['1950', 'May', 113],
        ['1951', 'Jan', 129], ['1951', 'Feb', 134], ['1951', 'Mar', 118], ['1951', 'Apr', 111], ['1951', 'May', 125],
        ['1952', 'Jan', 111], ['1952', 'Feb', 125], ['1952', 'Mar', 133], ['1952', 'Apr', 121], ['1952', 'May', 115],
        ['1953', 'Jan', 125], ['1953', 'Feb', 133], ['1953', 'Mar', 111], ['1953', 'Apr', 132], ['1953', 'May', 121],
        ['1954', 'Jan', 129], ['1954', 'Feb', 112], ['1954', 'Mar', 112], ['1954', 'Apr', 129], ['1954', 'May', 118],
        ['1955', 'Jan', 133], ['1955', 'Feb', 118], ['1955', 'Mar', 128], ['1955', 'Apr', 122], ['1955', 'May', 132]]

# Create the pandas DataFrame
flights = pd.DataFrame(data, columns=['year', 'month','passengers'])

# print dataframe.
flights.head()
# Out:
#    year month  passengers
# 0  1949   Jan         112
# 1  1949   Feb         118
# 2  1949   Mar         132
# 3  1949   Apr         129
# 4  1949   May         108

# %% [markdown]
# # **Line plot (Gráfico lineal)**

# %%
may_flights = flights.query("month == 'May'")
sns.lineplot(data=may_flights, x="year", y="passengers")
# Out:
# <Axes: xlabel='year', ylabel='passengers'>

# %% [markdown]
# ### Adjust size of the plot

# %%
sns.set(rc={"figure.figsize":(10, 8)}) # To adjust size

# %%
may_flights = flights.query("month == 'May'")
sns.lineplot(data=may_flights, x="year", y="passengers")
# Out:
# <Axes: xlabel='year', ylabel='passengers'>

# %% [markdown]
# # **Bar plot (Gráfico de barras)**

# %%
sns.set_theme(style="whitegrid")
sns.barplot(x="month",y="passengers",hue="year",data=flights)

# %% [markdown]
# # **Histograma**

# %%
sns.histplot(data=flights, x="passengers")

# %%
sns.histplot(data=flights, x="passengers", bins=5)

# %%
sns.histplot(data=flights, x="passengers", hue='year')

# %%
sns.histplot(data=flights, x="passengers", hue='year', multiple="stack")

# %% [markdown]
# # **Displot (Distribution plot)**

# %%
sns.displot(data=flights, x="passengers", hue='year', multiple="stack")

# %%
sns.set_theme(style="whitegrid")
sns.boxplot(data=flights, x="passengers", hue='year')

# %% [markdown]
# # **Heatmap**
#
# References
# * https://pythonbasics.org/seaborn-heatmap/
# * https://towardsdatascience.com/5-ways-to-use-a-seaborn-heatmap-python-tutorial-c79950f5add3
# * https://seaborn.pydata.org/generated/seaborn.heatmap.html

# %%
sns.set()
flights2 = flights.pivot("month", "year", "passengers")
sns.set(rc={"figure.figsize":(10, 8)})
ax = sns.heatmap(flights2)
plt.title("Heatmap Flight Data")
plt.show()

# %% [markdown]
# # Pie Diagram

# %% [markdown]
# ## Example 1

# %%
# Group by 'year' and sum the passengers for each year
yearly_passengers = flights.groupby('year')['passengers'].sum()
yearly_passengers
# Out:
# year
# 1949    599
# 1950    594
# 1951    617
# 1952    605
# 1953    622
# 1954    600
# 1955    633
# Name: passengers, dtype: int64

# %%
# Apply Seaborn's default style
sns.set_theme()

# Create a pie chart using Matplotlib's pie function
plt.figure(figsize=(8, 8))
colors = sns.color_palette("Set2", len(yearly_passengers))  # Use Seaborn's color palette

# Plot the pie chart
plt.pie(yearly_passengers, labels=yearly_passengers.index, autopct='%1.1f%%', startangle=90, colors=colors, wedgeprops={'edgecolor': 'black'})
plt.title('Distribution of Passengers by Year')
plt.ylabel('')  # Remove the y-label
plt.show()

# %% [markdown]
# ## Example 2

# %%
data = [35, 21, 29, 39, 11]
explode = [0.3, 0.02, 0.02, 0.02, 0.02]
labels = ["slice 1", "slice 2", "slice 3", "slice 4", "slice 5"]
colors = sns.color_palette("bright")
plt.pie(data, labels=labels, colors=colors, autopct="%0.0f%%", explode=explode)
plt.show()
