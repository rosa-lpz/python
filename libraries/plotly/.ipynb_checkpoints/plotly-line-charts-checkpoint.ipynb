# %%
import pandas as pd
import plotly.express as px

# %% [markdown]
# # Simple Line Chart

# %%
year = [2016,2017,2018,2019,2020,2021]
count = [45,46,47,48,50,51]

# Creating the Figure instance
fig = px.line(x=year, y=count)

# showing the plot
fig.show()

# %%
# From a dataframe
# initialize list of lists
count_year_list = [[2016,2017,2018,2019,2020,2021], [45,46,47,48,50,51]]
 
# Creating the pandas DataFrame with column the columns 'x', 'y'
count_by_year_df = pd.DataFrame(count_year_list, index=['year','count']).T
count_by_year_df
# Out:
#    year  count
# 0  2016     45
# 1  2017     46
# 2  2018     47
# 3  2019     48
# 4  2020     50
# 5  2021     51
