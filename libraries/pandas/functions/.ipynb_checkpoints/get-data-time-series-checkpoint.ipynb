# %% [markdown]
# # Get Data

# %%
import pandas as pd
import numpy as np

# %% [markdown]
# ## Creating a time series index

# %%
# Creating a time series index
dates = pd.date_range(start='2023-01-01', periods=100, freq='D')
values = np.random.randn(100).cumsum()
values2 = np.random.randn(100).cumsum()
dates
# Out:
# DatetimeIndex(['2023-01-01', '2023-01-02', '2023-01-03', '2023-01-04',
#                '2023-01-05', '2023-01-06', '2023-01-07', '2023-01-08',
#                '2023-01-09', '2023-01-10', '2023-01-11', '2023-01-12',
#                '2023-01-13', '2023-01-14', '2023-01-15', '2023-01-16',
#                '2023-01-17', '2023-01-18', '2023-01-19', '2023-01-20',
#                '2023-01-21', '2023-01-22', '2023-01-23', '2023-01-24',
#                '2023-01-25', '2023-01-26', '2023-01-27', '2023-01-28',
#                '2023-01-29', '2023-01-30', '2023-01-31', '2023-02-01',
#                '2023-02-02', '2023-02-03', '2023-02-04', '2023-02-05',
#                '2023-02-06', '2023-02-07', '2023-02-08', '2023-02-09',
#                '2023-02-10', '2023-02-11', '2023-02-12', '2023-02-13',
#                '2023-02-14', '2023-02-15', '2023-02-16', '2023-02-17',
#                '2023-02-18', '2023-02-19', '2023-02-20', '2023-02-21',
# ...

# %%
values
# Out:
# array([-0.24954801, -0.70591071, -0.74407457, -0.01137951,  0.74924718,
#         1.70372889,  1.83306052,  1.49716855,  1.08918804, -1.97195541,
#        -1.61183441, -2.95106566, -1.61984666, -2.70020864, -3.63662583,
#        -3.7031366 , -3.54470965, -3.65741853, -4.06792717, -3.95972594,
#        -2.93991938, -1.8521856 , -0.8942412 , -2.89452841, -1.34211699,
#        -1.19502921, -1.18002409,  0.89463604,  2.53107735,  2.63948511,
#         2.52406906,  2.67158868,  2.91761185,  2.38523162,  2.72763248,
#         2.0225401 ,  3.30827476,  3.182686  ,  2.42879207,  2.23464685,
#         3.01757002,  3.75369134,  2.56225368,  2.21572202,  2.70400488,
#         3.49660289,  3.34912303,  3.23947698,  3.39618743,  2.31817102,
#         2.90478732,  3.63718673,  2.57940626,  2.11671442,  3.13776076,
#         3.24606923,  3.783066  ,  4.53139444,  3.38741043,  2.61372759,
#         3.33178445,  3.15191062,  2.6713506 ,  2.72616481,  2.45023939,
# ...

# %%
# Creating a DataFrame from series data
df = pd.DataFrame({'Date': dates, 'Value': values, 'Value2':values2})
df.set_index('Date', inplace=True)
df
# Out:
#                 Value     Value2
# Date
# 2023-01-01  -0.570433   0.728371
# 2023-01-02   0.138079  -0.212016
# 2023-01-03  -0.503551  -1.041971
# 2023-01-04  -1.094235  -1.112375
# 2023-01-05  -1.964942  -0.169973
# ...               ...        ...
# 2023-04-06 -13.402335  -8.596140
# 2023-04-07 -13.669148  -8.504612
# 2023-04-08 -15.785811  -9.021156
# 2023-04-09 -14.084790  -9.439599
# 2023-04-10 -13.647479 -10.030306
#
# [100 rows x 2 columns]

# %% [markdown]
# ## Create dataframe

# %%
# Creating a time series index
dates = pd.date_range(start='2023-01-01', periods=100, freq='D')
values = np.random.randn(100).cumsum()
values2 = np.random.randn(100).cumsum()
dates

# %%
def create_df(dates, values, values2):
    df = pd.DataFrame({
        "date": pd.to_datetime(dates),
        "values": values,
        "values2": values2
    })
    return df

# %%
cols=["Value", "Value2"]
df= create_df(dates, values, values2)

df
# Out:
#          date     values    values2
# 0  2023-01-01  -0.570433   0.728371
# 1  2023-01-02   0.138079  -0.212016
# 2  2023-01-03  -0.503551  -1.041971
# 3  2023-01-04  -1.094235  -1.112375
# 4  2023-01-05  -1.964942  -0.169973
# ..        ...        ...        ...
# 95 2023-04-06 -13.402335  -8.596140
# 96 2023-04-07 -13.669148  -8.504612
# 97 2023-04-08 -15.785811  -9.021156
# 98 2023-04-09 -14.084790  -9.439599
# 99 2023-04-10 -13.647479 -10.030306
#
# [100 rows x 3 columns]

# %% [markdown]
# # Get data functions

# %%
def getData(start_date, end_date, cols):
    start_datetime =datetime.strptime(start_date, "%Y-%m-%d %H:%M:%$")
    end_datetime=datetime.strptime(start_date, "%Y-%m-%d %H:%M:%$")
    cols=list(set(cols))

    return(
    )

# %%
def getData(df,start_date, end_date, cols):
    dates = pd.date_range(start=start_date, end=end_date, freq="D")

    df = pd.DataFrame(index=dates, columns=cols)
    df.index.name = "date"

    # Filter by date
    result = df[
        (df["date"] >= start_date) &
        (df["date"] <= end_date)
    ]

    # Select the requested columns
    result = result[["date"] + cols]

    return result

    return df

# %%
cols=["Value", "Value2"]
df_data= getData("2023-01-02", "2026-03-07", cols)

df_data
# Out:
#            Value Value2
# date
# 2023-01-02   NaN    NaN
# 2023-01-03   NaN    NaN
# 2023-01-04   NaN    NaN
# 2023-01-05   NaN    NaN
# 2023-01-06   NaN    NaN
# ...          ...    ...
# 2026-03-03   NaN    NaN
# 2026-03-04   NaN    NaN
# 2026-03-05   NaN    NaN
# 2026-03-06   NaN    NaN
# 2026-03-07   NaN    NaN
#
# [1161 rows x 2 columns]
